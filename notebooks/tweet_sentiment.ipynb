# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, precision_score
import cudf
from cuml.feature_extraction.text import TfidfVectorizer

# %%
def display_scores(predictions, df):
    accuracy = accuracy_score((predictions > 0.5).astype(int), df['sentiment'].values.get())
    precision = precision_score((predictions > 0.5).astype(int), df['sentiment'].values.get())
    auc = roc_auc_score((predictions > 0.5).astype(int), df['sentiment'].values.get())
    recall = recall_score((predictions > 0.5).astype(int), df['sentiment'].values.get())
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Auc: {auc}')
    print(f'Recall: {recall}')

# %%
# %%time
sentiment140 = pd.read_csv('../data/external/sentiment140/training.1600000.processed.noemoticon.zip', encoding='latin-1', header=None, names=['sentiment', 'id', 'date', 'no_query', 'user', 'tweet'])

#MOVE DATAFRAME TO GPU
sentiment140 = cudf.from_pandas(sentiment140)
sentiment140 = sentiment140[['tweet', 'user', 'sentiment']]
sentiment140['sentiment'] = (sentiment140['sentiment']==4).astype(int)
print(type(sentiment140))
sentiment140
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# CPU times: user 4.26 s, sys: 200 ms, total: 4.46 s
# Wall time: 4.45 s
#                                                      tweet             user  \
# 0        @switchfoot http://twitpic.com/2y1zl - Awww, t...  _TheSpecialOne_
# 1        is upset that he can't update his Facebook by ...    scotthamilton
# 2        @Kenichan I dived many times for the ball. Man...         mattycus
# 3          my whole body feels itchy and like its on fire           ElleCTF
# 4        @nationwideclass no, it's not behaving at all....           Karoli
# ...                                                    ...              ...
# 1599995  Just woke up. Having no school is the best fee...  AmandaMarie1028
# 1599996  TheWDB.com - Very cool to hear old Walt interv...      TheWDBoards
# 1599997  Are you ready for your MoJo Makeover? Ask me f...           bpbabe
# 1599998  Happy 38th Birthday to my boo of alll time!!! ...     tinydiamondz
# 1599999  happy #charitytuesday @theNSPCC @SparksCharity...   RyanTrevMorris
#
#          sentiment
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1599995          1
# 1599996          1
# 1599997          1
# 1599998          1
# 1599999          1
#
# [1600000 rows x 3 columns]

# %%
# %%time
vec = TfidfVectorizer(stop_words='english')
tfidf_matrix = vec.fit_transform(sentiment140['tweet'])
# Out:
# CPU times: user 4.97 s, sys: 543 ms, total: 5.52 s
# Wall time: 5.53 s

# %%
# MOVE SPARSE ROW MATRIX TO CPU BECAUSE THE XGBOOST DMATRIX CONSTRUCTOR DOESN'T SUPPORT THE CUPY SPARSE ROW MATRIX
tfidf_cpu = tfidf_matrix.get()

# %%
X_train, X_valid, y_train, y_valid = train_test_split(tfidf_cpu, sentiment140['sentiment'], test_size=0.25)
dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)

# %%
params_lr_nought_1 = {'tree_method': 'gpu_hist', 'eval_metric': 'auc', 'objective': 'binary:logistic', 'learning_rate':0.1}
params_lr_nought_3 = {'tree_method': 'gpu_hist', 'eval_metric': 'auc', 'objective': 'binary:logistic', 'learning_rate':0.3}

# %%
eval_list = [(dvalid, 'validation'), (dtrain, 'train')]
num_round = 200

# %%
# %%time
bst_lr_nought_1 = xgb.train(params_lr_nought_1, dtrain, num_round, eval_list)
# Out:
# [0]	validation-auc:0.59333	train-auc:0.59439
# [1]	validation-auc:0.60595	train-auc:0.60686
# [2]	validation-auc:0.61200	train-auc:0.61297
# [3]	validation-auc:0.63267	train-auc:0.63331
# [4]	validation-auc:0.63243	train-auc:0.63315
# [5]	validation-auc:0.63880	train-auc:0.63960
# [6]	validation-auc:0.65321	train-auc:0.65426
# [7]	validation-auc:0.65869	train-auc:0.65990
# [8]	validation-auc:0.66205	train-auc:0.66325
# [9]	validation-auc:0.66237	train-auc:0.66356
# [10]	validation-auc:0.66530	train-auc:0.66647
# [11]	validation-auc:0.67117	train-auc:0.67222
# [12]	validation-auc:0.67364	train-auc:0.67482
# [13]	validation-auc:0.67858	train-auc:0.67994
# [14]	validation-auc:0.68135	train-auc:0.68267
# [15]	validation-auc:0.68707	train-auc:0.68841
# [16]	validation-auc:0.68935	train-auc:0.69077
# [17]	validation-auc:0.69485	train-auc:0.69641
# [18]	validation-auc:0.69877	train-auc:0.70035
# [19]	validation-auc:0.69906	train-auc:0.70065
# [20]	validation-auc:0.70122	train-auc:0.70277
# [21]	validation-auc:0.70122	train-auc:0.70279
# [22]	validation-auc:0.70347	train-auc:0.70500
# [23]	validation-auc:0.70590	train-auc:0.70753
# [24]	validation-auc:0.70763	train-auc:0.70921
# [25]	validation-auc:0.70953	train-auc:0.71100
# [26]	validation-auc:0.71018	train-auc:0.71169
# [27]	validation-auc:0.71063	train-auc:0.71213
# [28]	validation-auc:0.71314	train-auc:0.71456
# [29]	validation-auc:0.71552	train-auc:0.71700
# [30]	validation-auc:0.71688	train-auc:0.71847
# [31]	validation-auc:0.71925	train-auc:0.72089
# [32]	validation-auc:0.72079	train-auc:0.72254
# [33]	validation-auc:0.72201	train-auc:0.72381
# [34]	validation-auc:0.72420	train-auc:0.72606
# [35]	validation-auc:0.72530	train-auc:0.72720
# [36]	validation-auc:0.72781	train-auc:0.72989
# [37]	validation-auc:0.73092	train-auc:0.73326
# [38]	validation-auc:0.73183	train-auc:0.73411
# [39]	validation-auc:0.73316	train-auc:0.73532
# [40]	validation-auc:0.73457	train-auc:0.73668
# [41]	validation-auc:0.73606	train-auc:0.73809
# [42]	validation-auc:0.73881	train-auc:0.74068
# [43]	validation-auc:0.74004	train-auc:0.74191
# [44]	validation-auc:0.74131	train-auc:0.74325
# [45]	validation-auc:0.74395	train-auc:0.74613
# [46]	validation-auc:0.74520	train-auc:0.74760
# [47]	validation-auc:0.74591	train-auc:0.74843
# [48]	validation-auc:0.74827	train-auc:0.75071
# [49]	validation-auc:0.74850	train-auc:0.75091
# [50]	validation-auc:0.75050	train-auc:0.75290
# [51]	validation-auc:0.75076	train-auc:0.75314
# [52]	validation-auc:0.75205	train-auc:0.75433
# [53]	validation-auc:0.75230	train-auc:0.75456
# [54]	validation-auc:0.75312	train-auc:0.75542
# [55]	validation-auc:0.75491	train-auc:0.75715
# [56]	validation-auc:0.75619	train-auc:0.75837
# [57]	validation-auc:0.75694	train-auc:0.75906
# [58]	validation-auc:0.75825	train-auc:0.76050
# [59]	validation-auc:0.75859	train-auc:0.76083
# [60]	validation-auc:0.75901	train-auc:0.76130
# [61]	validation-auc:0.75963	train-auc:0.76196
# [62]	validation-auc:0.76020	train-auc:0.76247
# [63]	validation-auc:0.76085	train-auc:0.76328
# [64]	validation-auc:0.76107	train-auc:0.76358
# [65]	validation-auc:0.76144	train-auc:0.76397
# [66]	validation-auc:0.76202	train-auc:0.76459
# [67]	validation-auc:0.76253	train-auc:0.76513
# [68]	validation-auc:0.76319	train-auc:0.76574
# [69]	validation-auc:0.76427	train-auc:0.76681
# [70]	validation-auc:0.76458	train-auc:0.76707
# [71]	validation-auc:0.76502	train-auc:0.76761
# [72]	validation-auc:0.76518	train-auc:0.76780
# [73]	validation-auc:0.76543	train-auc:0.76803
# [74]	validation-auc:0.76616	train-auc:0.76878
# [75]	validation-auc:0.76650	train-auc:0.76911
# [76]	validation-auc:0.76727	train-auc:0.76992
# [77]	validation-auc:0.76749	train-auc:0.77013
# [78]	validation-auc:0.76813	train-auc:0.77075
# [79]	validation-auc:0.76823	train-auc:0.77089
# [80]	validation-auc:0.76882	train-auc:0.77150
# [81]	validation-auc:0.76900	train-auc:0.77170
# [82]	validation-auc:0.76962	train-auc:0.77232
# [83]	validation-auc:0.77007	train-auc:0.77290
# [84]	validation-auc:0.77054	train-auc:0.77342
# [85]	validation-auc:0.77153	train-auc:0.77448
# [86]	validation-auc:0.77205	train-auc:0.77495
# [87]	validation-auc:0.77259	train-auc:0.77546
# [88]	validation-auc:0.77271	train-auc:0.77557
# [89]	validation-auc:0.77335	train-auc:0.77616
# [90]	validation-auc:0.77359	train-auc:0.77634
# [91]	validation-auc:0.77400	train-auc:0.77682
# [92]	validation-auc:0.77436	train-auc:0.77718
# [93]	validation-auc:0.77478	train-auc:0.77759
# [94]	validation-auc:0.77506	train-auc:0.77786
# [95]	validation-auc:0.77516	train-auc:0.77799
# [96]	validation-auc:0.77540	train-auc:0.77823
# [97]	validation-auc:0.77610	train-auc:0.77896
# [98]	validation-auc:0.77660	train-auc:0.77948
# [99]	validation-auc:0.77700	train-auc:0.77993
# [100]	validation-auc:0.77720	train-auc:0.78014
# [101]	validation-auc:0.77774	train-auc:0.78068
# [102]	validation-auc:0.77806	train-auc:0.78100
# [103]	validation-auc:0.77824	train-auc:0.78122
# [104]	validation-auc:0.77891	train-auc:0.78188
# [105]	validation-auc:0.77902	train-auc:0.78205
# [106]	validation-auc:0.77945	train-auc:0.78253
# [107]	validation-auc:0.77985	train-auc:0.78293
# [108]	validation-auc:0.78012	train-auc:0.78321
# [109]	validation-auc:0.78043	train-auc:0.78354
# [110]	validation-auc:0.78104	train-auc:0.78425
# [111]	validation-auc:0.78183	train-auc:0.78496
# [112]	validation-auc:0.78224	train-auc:0.78537
# [113]	validation-auc:0.78236	train-auc:0.78547
# [114]	validation-auc:0.78249	train-auc:0.78560
# [115]	validation-auc:0.78285	train-auc:0.78593
# [116]	validation-auc:0.78322	train-auc:0.78629
# [117]	validation-auc:0.78366	train-auc:0.78679
# [118]	validation-auc:0.78386	train-auc:0.78697
# [119]	validation-auc:0.78406	train-auc:0.78713
# [120]	validation-auc:0.78466	train-auc:0.78776
# [121]	validation-auc:0.78503	train-auc:0.78810
# [122]	validation-auc:0.78524	train-auc:0.78836
# [123]	validation-auc:0.78550	train-auc:0.78866
# [124]	validation-auc:0.78558	train-auc:0.78878
# [125]	validation-auc:0.78594	train-auc:0.78915
# [126]	validation-auc:0.78626	train-auc:0.78948
# [127]	validation-auc:0.78661	train-auc:0.78984
# [128]	validation-auc:0.78691	train-auc:0.79014
# [129]	validation-auc:0.78722	train-auc:0.79046
# [130]	validation-auc:0.78747	train-auc:0.79074
# [131]	validation-auc:0.78763	train-auc:0.79090
# [132]	validation-auc:0.78783	train-auc:0.79112
# [133]	validation-auc:0.78829	train-auc:0.79160
# [134]	validation-auc:0.78868	train-auc:0.79202
# [135]	validation-auc:0.78904	train-auc:0.79238
# [136]	validation-auc:0.78927	train-auc:0.79264
# [137]	validation-auc:0.78942	train-auc:0.79279
# [138]	validation-auc:0.78974	train-auc:0.79313
# [139]	validation-auc:0.79012	train-auc:0.79349
# [140]	validation-auc:0.79027	train-auc:0.79365
# [141]	validation-auc:0.79050	train-auc:0.79390
# [142]	validation-auc:0.79077	train-auc:0.79418
# [143]	validation-auc:0.79083	train-auc:0.79425
# [144]	validation-auc:0.79104	train-auc:0.79447
# [145]	validation-auc:0.79119	train-auc:0.79463
# [146]	validation-auc:0.79182	train-auc:0.79522
# [147]	validation-auc:0.79199	train-auc:0.79539
# [148]	validation-auc:0.79219	train-auc:0.79565
# [149]	validation-auc:0.79251	train-auc:0.79602
# [150]	validation-auc:0.79280	train-auc:0.79627
# [151]	validation-auc:0.79295	train-auc:0.79643
# [152]	validation-auc:0.79322	train-auc:0.79665
# [153]	validation-auc:0.79334	train-auc:0.79679
# [154]	validation-auc:0.79343	train-auc:0.79688
# [155]	validation-auc:0.79347	train-auc:0.79691
# [156]	validation-auc:0.79359	train-auc:0.79704
# [157]	validation-auc:0.79378	train-auc:0.79727
# [158]	validation-auc:0.79394	train-auc:0.79744
# [159]	validation-auc:0.79439	train-auc:0.79788
# [160]	validation-auc:0.79445	train-auc:0.79796
# [161]	validation-auc:0.79456	train-auc:0.79811
# [162]	validation-auc:0.79474	train-auc:0.79828
# [163]	validation-auc:0.79486	train-auc:0.79841
# [164]	validation-auc:0.79493	train-auc:0.79849
# [165]	validation-auc:0.79514	train-auc:0.79872
# [166]	validation-auc:0.79529	train-auc:0.79884
# [167]	validation-auc:0.79558	train-auc:0.79913
# [168]	validation-auc:0.79571	train-auc:0.79930
# [169]	validation-auc:0.79575	train-auc:0.79942
# [170]	validation-auc:0.79602	train-auc:0.79973
# [171]	validation-auc:0.79632	train-auc:0.79997
# [172]	validation-auc:0.79653	train-auc:0.80015
# [173]	validation-auc:0.79673	train-auc:0.80032
# [174]	validation-auc:0.79692	train-auc:0.80053
# [175]	validation-auc:0.79722	train-auc:0.80082
# [176]	validation-auc:0.79750	train-auc:0.80111
# [177]	validation-auc:0.79760	train-auc:0.80120
# [178]	validation-auc:0.79756	train-auc:0.80121
# [179]	validation-auc:0.79771	train-auc:0.80136
# [180]	validation-auc:0.79775	train-auc:0.80144
# [181]	validation-auc:0.79783	train-auc:0.80151
# [182]	validation-auc:0.79801	train-auc:0.80170
# [183]	validation-auc:0.79804	train-auc:0.80173
# [184]	validation-auc:0.79815	train-auc:0.80184
# [185]	validation-auc:0.79828	train-auc:0.80197
# [186]	validation-auc:0.79851	train-auc:0.80224
# [187]	validation-auc:0.79855	train-auc:0.80230
# [188]	validation-auc:0.79864	train-auc:0.80243
# [189]	validation-auc:0.79880	train-auc:0.80261
# [190]	validation-auc:0.79909	train-auc:0.80287
# [191]	validation-auc:0.79920	train-auc:0.80300
# [192]	validation-auc:0.79936	train-auc:0.80320
# [193]	validation-auc:0.79940	train-auc:0.80327
# [194]	validation-auc:0.79945	train-auc:0.80333
# [195]	validation-auc:0.79958	train-auc:0.80350
# [196]	validation-auc:0.79986	train-auc:0.80376
# [197]	validation-auc:0.79995	train-auc:0.80390
# [198]	validation-auc:0.80004	train-auc:0.80401
# [199]	validation-auc:0.80030	train-auc:0.80427
# CPU times: user 17min 25s, sys: 7min 24s, total: 24min 50s
# Wall time: 24min 48s

# %%
# %%time
bst_lr_nought_3 = xgb.train(params_lr_nought_3, dtrain, num_round, eval_list)
# Out:
# [0]	validation-auc:0.59333	train-auc:0.59439
# [1]	validation-auc:0.62009	train-auc:0.62106
# [2]	validation-auc:0.64635	train-auc:0.64695
# [3]	validation-auc:0.66263	train-auc:0.66390
# [4]	validation-auc:0.67398	train-auc:0.67515
# [5]	validation-auc:0.67734	train-auc:0.67849
# [6]	validation-auc:0.68832	train-auc:0.68945
# [7]	validation-auc:0.69871	train-auc:0.69980
# [8]	validation-auc:0.70585	train-auc:0.70745
# [9]	validation-auc:0.70954	train-auc:0.71128
# [10]	validation-auc:0.71246	train-auc:0.71430
# [11]	validation-auc:0.71532	train-auc:0.71720
# [12]	validation-auc:0.71844	train-auc:0.72033
# [13]	validation-auc:0.72594	train-auc:0.72785
# [14]	validation-auc:0.73010	train-auc:0.73211
# [15]	validation-auc:0.73773	train-auc:0.73979
# [16]	validation-auc:0.74073	train-auc:0.74272
# [17]	validation-auc:0.74436	train-auc:0.74638
# [18]	validation-auc:0.74656	train-auc:0.74872
# [19]	validation-auc:0.74987	train-auc:0.75234
# [20]	validation-auc:0.75423	train-auc:0.75678
# [21]	validation-auc:0.75468	train-auc:0.75733
# [22]	validation-auc:0.75755	train-auc:0.76011
# [23]	validation-auc:0.75928	train-auc:0.76179
# [24]	validation-auc:0.76160	train-auc:0.76414
# [25]	validation-auc:0.76298	train-auc:0.76563
# [26]	validation-auc:0.76452	train-auc:0.76737
# [27]	validation-auc:0.76617	train-auc:0.76901
# [28]	validation-auc:0.76758	train-auc:0.77049
# [29]	validation-auc:0.76914	train-auc:0.77208
# [30]	validation-auc:0.77067	train-auc:0.77361
# [31]	validation-auc:0.77224	train-auc:0.77525
# [32]	validation-auc:0.77392	train-auc:0.77707
# [33]	validation-auc:0.77537	train-auc:0.77847
# [34]	validation-auc:0.77644	train-auc:0.77952
# [35]	validation-auc:0.77763	train-auc:0.78081
# [36]	validation-auc:0.77875	train-auc:0.78191
# [37]	validation-auc:0.77974	train-auc:0.78305
# [38]	validation-auc:0.78049	train-auc:0.78388
# [39]	validation-auc:0.78107	train-auc:0.78454
# [40]	validation-auc:0.78157	train-auc:0.78510
# [41]	validation-auc:0.78220	train-auc:0.78577
# [42]	validation-auc:0.78387	train-auc:0.78756
# [43]	validation-auc:0.78506	train-auc:0.78875
# [44]	validation-auc:0.78576	train-auc:0.78946
# [45]	validation-auc:0.78643	train-auc:0.79012
# [46]	validation-auc:0.78781	train-auc:0.79156
# [47]	validation-auc:0.78855	train-auc:0.79230
# [48]	validation-auc:0.78937	train-auc:0.79318
# [49]	validation-auc:0.78995	train-auc:0.79372
# [50]	validation-auc:0.79066	train-auc:0.79449
# [51]	validation-auc:0.79145	train-auc:0.79541
# [52]	validation-auc:0.79221	train-auc:0.79612
# [53]	validation-auc:0.79279	train-auc:0.79681
# [54]	validation-auc:0.79319	train-auc:0.79727
# [55]	validation-auc:0.79402	train-auc:0.79806
# [56]	validation-auc:0.79460	train-auc:0.79863
# [57]	validation-auc:0.79507	train-auc:0.79911
# [58]	validation-auc:0.79557	train-auc:0.79961
# [59]	validation-auc:0.79587	train-auc:0.79993
# [60]	validation-auc:0.79617	train-auc:0.80025
# [61]	validation-auc:0.79682	train-auc:0.80098
# [62]	validation-auc:0.79725	train-auc:0.80148
# [63]	validation-auc:0.79774	train-auc:0.80197
# [64]	validation-auc:0.79879	train-auc:0.80302
# [65]	validation-auc:0.79908	train-auc:0.80332
# [66]	validation-auc:0.79930	train-auc:0.80356
# [67]	validation-auc:0.79980	train-auc:0.80409
# [68]	validation-auc:0.80006	train-auc:0.80440
# [69]	validation-auc:0.80040	train-auc:0.80474
# [70]	validation-auc:0.80090	train-auc:0.80528
# [71]	validation-auc:0.80132	train-auc:0.80580
# [72]	validation-auc:0.80225	train-auc:0.80663
# [73]	validation-auc:0.80256	train-auc:0.80700
# [74]	validation-auc:0.80298	train-auc:0.80750
# [75]	validation-auc:0.80352	train-auc:0.80800
# [76]	validation-auc:0.80393	train-auc:0.80839
# [77]	validation-auc:0.80412	train-auc:0.80860
# [78]	validation-auc:0.80446	train-auc:0.80900
# [79]	validation-auc:0.80463	train-auc:0.80928
# [80]	validation-auc:0.80481	train-auc:0.80949
# [81]	validation-auc:0.80520	train-auc:0.80999
# [82]	validation-auc:0.80572	train-auc:0.81052
# [83]	validation-auc:0.80616	train-auc:0.81101
# [84]	validation-auc:0.80642	train-auc:0.81125
# [85]	validation-auc:0.80685	train-auc:0.81171
# [86]	validation-auc:0.80715	train-auc:0.81209
# [87]	validation-auc:0.80729	train-auc:0.81224
# [88]	validation-auc:0.80770	train-auc:0.81264
# [89]	validation-auc:0.80811	train-auc:0.81306
# [90]	validation-auc:0.80848	train-auc:0.81348
# [91]	validation-auc:0.80867	train-auc:0.81370
# [92]	validation-auc:0.80913	train-auc:0.81416
# [93]	validation-auc:0.80924	train-auc:0.81425
# [94]	validation-auc:0.80951	train-auc:0.81451
# [95]	validation-auc:0.80969	train-auc:0.81472
# [96]	validation-auc:0.80999	train-auc:0.81511
# [97]	validation-auc:0.81046	train-auc:0.81563
# [98]	validation-auc:0.81078	train-auc:0.81596
# [99]	validation-auc:0.81119	train-auc:0.81639
# [100]	validation-auc:0.81135	train-auc:0.81659
# [101]	validation-auc:0.81164	train-auc:0.81693
# [102]	validation-auc:0.81198	train-auc:0.81726
# [103]	validation-auc:0.81220	train-auc:0.81753
# [104]	validation-auc:0.81253	train-auc:0.81780
# [105]	validation-auc:0.81290	train-auc:0.81823
# [106]	validation-auc:0.81322	train-auc:0.81865
# [107]	validation-auc:0.81355	train-auc:0.81903
# [108]	validation-auc:0.81388	train-auc:0.81938
# [109]	validation-auc:0.81408	train-auc:0.81960
# [110]	validation-auc:0.81433	train-auc:0.81985
# [111]	validation-auc:0.81467	train-auc:0.82021
# [112]	validation-auc:0.81499	train-auc:0.82058
# [113]	validation-auc:0.81523	train-auc:0.82086
# [114]	validation-auc:0.81556	train-auc:0.82125
# [115]	validation-auc:0.81581	train-auc:0.82154
# [116]	validation-auc:0.81614	train-auc:0.82188
# [117]	validation-auc:0.81634	train-auc:0.82209
# [118]	validation-auc:0.81671	train-auc:0.82239
# [119]	validation-auc:0.81689	train-auc:0.82257
# [120]	validation-auc:0.81712	train-auc:0.82284
# [121]	validation-auc:0.81732	train-auc:0.82305
# [122]	validation-auc:0.81754	train-auc:0.82332
# [123]	validation-auc:0.81791	train-auc:0.82368
# [124]	validation-auc:0.81798	train-auc:0.82376
# [125]	validation-auc:0.81797	train-auc:0.82379
# [126]	validation-auc:0.81818	train-auc:0.82397
# [127]	validation-auc:0.81835	train-auc:0.82414
# [128]	validation-auc:0.81861	train-auc:0.82446
# [129]	validation-auc:0.81880	train-auc:0.82470
# [130]	validation-auc:0.81907	train-auc:0.82496
# [131]	validation-auc:0.81935	train-auc:0.82523
# [132]	validation-auc:0.81966	train-auc:0.82554
# [133]	validation-auc:0.81973	train-auc:0.82567
# [134]	validation-auc:0.82000	train-auc:0.82591
# [135]	validation-auc:0.82026	train-auc:0.82621
# [136]	validation-auc:0.82043	train-auc:0.82645
# [137]	validation-auc:0.82066	train-auc:0.82666
# [138]	validation-auc:0.82090	train-auc:0.82696
# [139]	validation-auc:0.82117	train-auc:0.82726
# [140]	validation-auc:0.82123	train-auc:0.82733
# [141]	validation-auc:0.82145	train-auc:0.82757
# [142]	validation-auc:0.82153	train-auc:0.82772
# [143]	validation-auc:0.82175	train-auc:0.82795
# [144]	validation-auc:0.82177	train-auc:0.82800
# [145]	validation-auc:0.82188	train-auc:0.82815
# [146]	validation-auc:0.82200	train-auc:0.82828
# [147]	validation-auc:0.82209	train-auc:0.82843
# [148]	validation-auc:0.82218	train-auc:0.82857
# [149]	validation-auc:0.82232	train-auc:0.82873
# [150]	validation-auc:0.82245	train-auc:0.82890
# [151]	validation-auc:0.82254	train-auc:0.82904
# [152]	validation-auc:0.82268	train-auc:0.82921
# [153]	validation-auc:0.82281	train-auc:0.82939
# [154]	validation-auc:0.82291	train-auc:0.82950
# [155]	validation-auc:0.82305	train-auc:0.82968
# [156]	validation-auc:0.82327	train-auc:0.82988
# [157]	validation-auc:0.82353	train-auc:0.83017
# [158]	validation-auc:0.82367	train-auc:0.83033
# [159]	validation-auc:0.82374	train-auc:0.83042
# [160]	validation-auc:0.82390	train-auc:0.83065
# [161]	validation-auc:0.82392	train-auc:0.83070
# [162]	validation-auc:0.82413	train-auc:0.83093
# [163]	validation-auc:0.82437	train-auc:0.83120
# [164]	validation-auc:0.82458	train-auc:0.83144
# [165]	validation-auc:0.82468	train-auc:0.83157
# [166]	validation-auc:0.82478	train-auc:0.83173
# [167]	validation-auc:0.82498	train-auc:0.83194
# [168]	validation-auc:0.82526	train-auc:0.83224
# [169]	validation-auc:0.82529	train-auc:0.83232
# [170]	validation-auc:0.82546	train-auc:0.83249
# [171]	validation-auc:0.82564	train-auc:0.83268
# [172]	validation-auc:0.82583	train-auc:0.83286
# [173]	validation-auc:0.82595	train-auc:0.83305
# [174]	validation-auc:0.82614	train-auc:0.83325
# [175]	validation-auc:0.82625	train-auc:0.83341
# [176]	validation-auc:0.82636	train-auc:0.83356
# [177]	validation-auc:0.82650	train-auc:0.83373
# [178]	validation-auc:0.82659	train-auc:0.83384
# [179]	validation-auc:0.82668	train-auc:0.83395
# [180]	validation-auc:0.82680	train-auc:0.83410
# [181]	validation-auc:0.82690	train-auc:0.83428
# [182]	validation-auc:0.82696	train-auc:0.83440
# [183]	validation-auc:0.82716	train-auc:0.83463
# [184]	validation-auc:0.82726	train-auc:0.83481
# [185]	validation-auc:0.82737	train-auc:0.83496
# [186]	validation-auc:0.82753	train-auc:0.83513
# [187]	validation-auc:0.82765	train-auc:0.83528
# [188]	validation-auc:0.82773	train-auc:0.83539
# [189]	validation-auc:0.82785	train-auc:0.83554
# [190]	validation-auc:0.82803	train-auc:0.83579
# [191]	validation-auc:0.82813	train-auc:0.83592
# [192]	validation-auc:0.82825	train-auc:0.83608
# [193]	validation-auc:0.82827	train-auc:0.83610
# [194]	validation-auc:0.82839	train-auc:0.83626
# [195]	validation-auc:0.82847	train-auc:0.83638
# [196]	validation-auc:0.82863	train-auc:0.83656
# [197]	validation-auc:0.82881	train-auc:0.83671
# [198]	validation-auc:0.82901	train-auc:0.83692
# [199]	validation-auc:0.82916	train-auc:0.83707
# CPU times: user 15min 5s, sys: 6min 19s, total: 21min 25s
# Wall time: 21min 24s

# %%
# %%time
bst_lr_nought_3_400_round = xgb.train(params_lr_nought_3, dtrain, 400, eval_list)
# Out:
# [0]	validation-auc:0.59333	train-auc:0.59439
# [1]	validation-auc:0.62009	train-auc:0.62106
# [2]	validation-auc:0.64635	train-auc:0.64695
# [3]	validation-auc:0.66263	train-auc:0.66390
# [4]	validation-auc:0.67398	train-auc:0.67515
# [5]	validation-auc:0.67734	train-auc:0.67849
# [6]	validation-auc:0.68832	train-auc:0.68945
# [7]	validation-auc:0.69871	train-auc:0.69980
# [8]	validation-auc:0.70585	train-auc:0.70745
# [9]	validation-auc:0.70954	train-auc:0.71128
# [10]	validation-auc:0.71246	train-auc:0.71430
# [11]	validation-auc:0.71532	train-auc:0.71720
# [12]	validation-auc:0.71844	train-auc:0.72033
# [13]	validation-auc:0.72594	train-auc:0.72785
# [14]	validation-auc:0.73010	train-auc:0.73211
# [15]	validation-auc:0.73773	train-auc:0.73979
# [16]	validation-auc:0.74073	train-auc:0.74272
# [17]	validation-auc:0.74436	train-auc:0.74638
# [18]	validation-auc:0.74656	train-auc:0.74872
# [19]	validation-auc:0.74987	train-auc:0.75234
# [20]	validation-auc:0.75423	train-auc:0.75678
# [21]	validation-auc:0.75468	train-auc:0.75733
# [22]	validation-auc:0.75755	train-auc:0.76011
# [23]	validation-auc:0.75928	train-auc:0.76179
# [24]	validation-auc:0.76160	train-auc:0.76414
# [25]	validation-auc:0.76298	train-auc:0.76563
# [26]	validation-auc:0.76452	train-auc:0.76737
# [27]	validation-auc:0.76617	train-auc:0.76901
# [28]	validation-auc:0.76758	train-auc:0.77049
# [29]	validation-auc:0.76914	train-auc:0.77208
# [30]	validation-auc:0.77067	train-auc:0.77361
# [31]	validation-auc:0.77224	train-auc:0.77525
# [32]	validation-auc:0.77392	train-auc:0.77707
# [33]	validation-auc:0.77537	train-auc:0.77847
# [34]	validation-auc:0.77644	train-auc:0.77952
# [35]	validation-auc:0.77763	train-auc:0.78081
# [36]	validation-auc:0.77875	train-auc:0.78191
# [37]	validation-auc:0.77974	train-auc:0.78305
# [38]	validation-auc:0.78049	train-auc:0.78388
# [39]	validation-auc:0.78107	train-auc:0.78454
# [40]	validation-auc:0.78157	train-auc:0.78510
# [41]	validation-auc:0.78220	train-auc:0.78577
# [42]	validation-auc:0.78387	train-auc:0.78756
# [43]	validation-auc:0.78506	train-auc:0.78875
# [44]	validation-auc:0.78576	train-auc:0.78946
# [45]	validation-auc:0.78643	train-auc:0.79012
# [46]	validation-auc:0.78781	train-auc:0.79156
# [47]	validation-auc:0.78855	train-auc:0.79230
# [48]	validation-auc:0.78937	train-auc:0.79318
# [49]	validation-auc:0.78995	train-auc:0.79372
# [50]	validation-auc:0.79066	train-auc:0.79449
# [51]	validation-auc:0.79145	train-auc:0.79541
# [52]	validation-auc:0.79221	train-auc:0.79612
# [53]	validation-auc:0.79279	train-auc:0.79681
# [54]	validation-auc:0.79319	train-auc:0.79727
# [55]	validation-auc:0.79402	train-auc:0.79806
# [56]	validation-auc:0.79460	train-auc:0.79863
# [57]	validation-auc:0.79507	train-auc:0.79911
# [58]	validation-auc:0.79557	train-auc:0.79961
# [59]	validation-auc:0.79587	train-auc:0.79993
# [60]	validation-auc:0.79617	train-auc:0.80025
# [61]	validation-auc:0.79682	train-auc:0.80098
# [62]	validation-auc:0.79725	train-auc:0.80148
# [63]	validation-auc:0.79774	train-auc:0.80197
# [64]	validation-auc:0.79879	train-auc:0.80302
# [65]	validation-auc:0.79908	train-auc:0.80332
# [66]	validation-auc:0.79930	train-auc:0.80356
# [67]	validation-auc:0.79980	train-auc:0.80409
# [68]	validation-auc:0.80006	train-auc:0.80440
# [69]	validation-auc:0.80040	train-auc:0.80474
# [70]	validation-auc:0.80090	train-auc:0.80528
# [71]	validation-auc:0.80132	train-auc:0.80580
# [72]	validation-auc:0.80225	train-auc:0.80663
# [73]	validation-auc:0.80256	train-auc:0.80700
# [74]	validation-auc:0.80298	train-auc:0.80750
# [75]	validation-auc:0.80352	train-auc:0.80800
# [76]	validation-auc:0.80393	train-auc:0.80839
# [77]	validation-auc:0.80412	train-auc:0.80860
# [78]	validation-auc:0.80446	train-auc:0.80900
# [79]	validation-auc:0.80463	train-auc:0.80928
# [80]	validation-auc:0.80481	train-auc:0.80949
# [81]	validation-auc:0.80520	train-auc:0.80999
# [82]	validation-auc:0.80572	train-auc:0.81052
# [83]	validation-auc:0.80616	train-auc:0.81101
# [84]	validation-auc:0.80642	train-auc:0.81125
# [85]	validation-auc:0.80685	train-auc:0.81171
# [86]	validation-auc:0.80715	train-auc:0.81209
# [87]	validation-auc:0.80729	train-auc:0.81224
# [88]	validation-auc:0.80770	train-auc:0.81264
# [89]	validation-auc:0.80811	train-auc:0.81306
# [90]	validation-auc:0.80848	train-auc:0.81348
# [91]	validation-auc:0.80867	train-auc:0.81370
# [92]	validation-auc:0.80913	train-auc:0.81416
# [93]	validation-auc:0.80924	train-auc:0.81425
# [94]	validation-auc:0.80951	train-auc:0.81451
# [95]	validation-auc:0.80969	train-auc:0.81472
# [96]	validation-auc:0.80999	train-auc:0.81511
# [97]	validation-auc:0.81046	train-auc:0.81563
# [98]	validation-auc:0.81078	train-auc:0.81596
# [99]	validation-auc:0.81119	train-auc:0.81639
# [100]	validation-auc:0.81135	train-auc:0.81659
# [101]	validation-auc:0.81164	train-auc:0.81693
# [102]	validation-auc:0.81198	train-auc:0.81726
# [103]	validation-auc:0.81220	train-auc:0.81753
# [104]	validation-auc:0.81253	train-auc:0.81780
# [105]	validation-auc:0.81290	train-auc:0.81823
# [106]	validation-auc:0.81322	train-auc:0.81865
# [107]	validation-auc:0.81355	train-auc:0.81903
# [108]	validation-auc:0.81388	train-auc:0.81938
# [109]	validation-auc:0.81408	train-auc:0.81960
# [110]	validation-auc:0.81433	train-auc:0.81985
# [111]	validation-auc:0.81467	train-auc:0.82021
# [112]	validation-auc:0.81499	train-auc:0.82058
# [113]	validation-auc:0.81523	train-auc:0.82086
# [114]	validation-auc:0.81556	train-auc:0.82125
# [115]	validation-auc:0.81581	train-auc:0.82154
# [116]	validation-auc:0.81614	train-auc:0.82188
# [117]	validation-auc:0.81634	train-auc:0.82209
# [118]	validation-auc:0.81671	train-auc:0.82239
# [119]	validation-auc:0.81689	train-auc:0.82257
# [120]	validation-auc:0.81712	train-auc:0.82284
# [121]	validation-auc:0.81732	train-auc:0.82305
# [122]	validation-auc:0.81754	train-auc:0.82332
# [123]	validation-auc:0.81791	train-auc:0.82368
# [124]	validation-auc:0.81798	train-auc:0.82376
# [125]	validation-auc:0.81797	train-auc:0.82379
# [126]	validation-auc:0.81818	train-auc:0.82397
# [127]	validation-auc:0.81835	train-auc:0.82414
# [128]	validation-auc:0.81861	train-auc:0.82446
# [129]	validation-auc:0.81880	train-auc:0.82470
# [130]	validation-auc:0.81907	train-auc:0.82496
# [131]	validation-auc:0.81935	train-auc:0.82523
# [132]	validation-auc:0.81966	train-auc:0.82554
# [133]	validation-auc:0.81973	train-auc:0.82567
# [134]	validation-auc:0.82000	train-auc:0.82591
# [135]	validation-auc:0.82026	train-auc:0.82621
# [136]	validation-auc:0.82043	train-auc:0.82645
# [137]	validation-auc:0.82066	train-auc:0.82666
# [138]	validation-auc:0.82090	train-auc:0.82696
# [139]	validation-auc:0.82117	train-auc:0.82726
# [140]	validation-auc:0.82123	train-auc:0.82733
# [141]	validation-auc:0.82145	train-auc:0.82757
# [142]	validation-auc:0.82153	train-auc:0.82772
# [143]	validation-auc:0.82175	train-auc:0.82795
# [144]	validation-auc:0.82177	train-auc:0.82800
# [145]	validation-auc:0.82188	train-auc:0.82815
# [146]	validation-auc:0.82200	train-auc:0.82828
# [147]	validation-auc:0.82209	train-auc:0.82843
# [148]	validation-auc:0.82218	train-auc:0.82857
# [149]	validation-auc:0.82232	train-auc:0.82873
# [150]	validation-auc:0.82245	train-auc:0.82890
# [151]	validation-auc:0.82254	train-auc:0.82904
# [152]	validation-auc:0.82268	train-auc:0.82921
# [153]	validation-auc:0.82281	train-auc:0.82939
# [154]	validation-auc:0.82291	train-auc:0.82950
# [155]	validation-auc:0.82305	train-auc:0.82968
# [156]	validation-auc:0.82327	train-auc:0.82988
# [157]	validation-auc:0.82353	train-auc:0.83017
# [158]	validation-auc:0.82367	train-auc:0.83033
# [159]	validation-auc:0.82374	train-auc:0.83042
# [160]	validation-auc:0.82390	train-auc:0.83065
# [161]	validation-auc:0.82392	train-auc:0.83070
# [162]	validation-auc:0.82413	train-auc:0.83093
# [163]	validation-auc:0.82437	train-auc:0.83120
# [164]	validation-auc:0.82458	train-auc:0.83144
# [165]	validation-auc:0.82468	train-auc:0.83157
# [166]	validation-auc:0.82478	train-auc:0.83173
# [167]	validation-auc:0.82498	train-auc:0.83194
# [168]	validation-auc:0.82526	train-auc:0.83224
# [169]	validation-auc:0.82529	train-auc:0.83232
# [170]	validation-auc:0.82546	train-auc:0.83249
# [171]	validation-auc:0.82564	train-auc:0.83268
# [172]	validation-auc:0.82583	train-auc:0.83286
# [173]	validation-auc:0.82595	train-auc:0.83305
# [174]	validation-auc:0.82614	train-auc:0.83325
# [175]	validation-auc:0.82625	train-auc:0.83341
# [176]	validation-auc:0.82636	train-auc:0.83356
# [177]	validation-auc:0.82650	train-auc:0.83373
# [178]	validation-auc:0.82659	train-auc:0.83384
# [179]	validation-auc:0.82668	train-auc:0.83395
# [180]	validation-auc:0.82680	train-auc:0.83410
# [181]	validation-auc:0.82690	train-auc:0.83428
# [182]	validation-auc:0.82696	train-auc:0.83440
# [183]	validation-auc:0.82716	train-auc:0.83463
# [184]	validation-auc:0.82726	train-auc:0.83481
# [185]	validation-auc:0.82737	train-auc:0.83496
# [186]	validation-auc:0.82753	train-auc:0.83513
# [187]	validation-auc:0.82765	train-auc:0.83528
# [188]	validation-auc:0.82773	train-auc:0.83539
# [189]	validation-auc:0.82785	train-auc:0.83554
# [190]	validation-auc:0.82803	train-auc:0.83579
# [191]	validation-auc:0.82813	train-auc:0.83592
# [192]	validation-auc:0.82825	train-auc:0.83608
# [193]	validation-auc:0.82827	train-auc:0.83610
# [194]	validation-auc:0.82839	train-auc:0.83626
# [195]	validation-auc:0.82847	train-auc:0.83638
# [196]	validation-auc:0.82863	train-auc:0.83656
# [197]	validation-auc:0.82881	train-auc:0.83671
# [198]	validation-auc:0.82901	train-auc:0.83692
# [199]	validation-auc:0.82916	train-auc:0.83707
# [200]	validation-auc:0.82924	train-auc:0.83720
# [201]	validation-auc:0.82937	train-auc:0.83734
# [202]	validation-auc:0.82946	train-auc:0.83747
# [203]	validation-auc:0.82961	train-auc:0.83767
# [204]	validation-auc:0.82967	train-auc:0.83775
# [205]	validation-auc:0.82979	train-auc:0.83786
# [206]	validation-auc:0.82990	train-auc:0.83800
# [207]	validation-auc:0.82999	train-auc:0.83809
# [208]	validation-auc:0.83009	train-auc:0.83819
# [209]	validation-auc:0.83019	train-auc:0.83831
# [210]	validation-auc:0.83030	train-auc:0.83844
# [211]	validation-auc:0.83035	train-auc:0.83854
# [212]	validation-auc:0.83044	train-auc:0.83866
# [213]	validation-auc:0.83050	train-auc:0.83871
# [214]	validation-auc:0.83063	train-auc:0.83885
# [215]	validation-auc:0.83075	train-auc:0.83895
# [216]	validation-auc:0.83088	train-auc:0.83907
# [217]	validation-auc:0.83092	train-auc:0.83911
# [218]	validation-auc:0.83102	train-auc:0.83922
# [219]	validation-auc:0.83112	train-auc:0.83933
# [220]	validation-auc:0.83120	train-auc:0.83942
# [221]	validation-auc:0.83127	train-auc:0.83955
# [222]	validation-auc:0.83140	train-auc:0.83969
# [223]	validation-auc:0.83147	train-auc:0.83981
# [224]	validation-auc:0.83159	train-auc:0.83993
# [225]	validation-auc:0.83171	train-auc:0.84008
# [226]	validation-auc:0.83183	train-auc:0.84022
# [227]	validation-auc:0.83198	train-auc:0.84035
# [228]	validation-auc:0.83203	train-auc:0.84044
# [229]	validation-auc:0.83210	train-auc:0.84053
# [230]	validation-auc:0.83216	train-auc:0.84063
# [231]	validation-auc:0.83227	train-auc:0.84073
# [232]	validation-auc:0.83235	train-auc:0.84081
# [233]	validation-auc:0.83250	train-auc:0.84101
# [234]	validation-auc:0.83264	train-auc:0.84116
# [235]	validation-auc:0.83272	train-auc:0.84128
# [236]	validation-auc:0.83279	train-auc:0.84137
# [237]	validation-auc:0.83288	train-auc:0.84147
# [238]	validation-auc:0.83295	train-auc:0.84157
# [239]	validation-auc:0.83307	train-auc:0.84171
# [240]	validation-auc:0.83316	train-auc:0.84182
# [241]	validation-auc:0.83322	train-auc:0.84192
# [242]	validation-auc:0.83330	train-auc:0.84201
# [243]	validation-auc:0.83338	train-auc:0.84211
# [244]	validation-auc:0.83346	train-auc:0.84223
# [245]	validation-auc:0.83354	train-auc:0.84232
# [246]	validation-auc:0.83360	train-auc:0.84242
# [247]	validation-auc:0.83370	train-auc:0.84255
# [248]	validation-auc:0.83378	train-auc:0.84262
# [249]	validation-auc:0.83390	train-auc:0.84275
# [250]	validation-auc:0.83400	train-auc:0.84286
# [251]	validation-auc:0.83405	train-auc:0.84294
# [252]	validation-auc:0.83405	train-auc:0.84300
# [253]	validation-auc:0.83413	train-auc:0.84310
# [254]	validation-auc:0.83421	train-auc:0.84320
# [255]	validation-auc:0.83422	train-auc:0.84321
# [256]	validation-auc:0.83430	train-auc:0.84330
# [257]	validation-auc:0.83432	train-auc:0.84336
# [258]	validation-auc:0.83443	train-auc:0.84348
# [259]	validation-auc:0.83451	train-auc:0.84360
# [260]	validation-auc:0.83457	train-auc:0.84369
# [261]	validation-auc:0.83462	train-auc:0.84377
# [262]	validation-auc:0.83470	train-auc:0.84387
# [263]	validation-auc:0.83476	train-auc:0.84395
# [264]	validation-auc:0.83479	train-auc:0.84400
# [265]	validation-auc:0.83488	train-auc:0.84410
# [266]	validation-auc:0.83493	train-auc:0.84417
# [267]	validation-auc:0.83497	train-auc:0.84426
# [268]	validation-auc:0.83500	train-auc:0.84432
# [269]	validation-auc:0.83508	train-auc:0.84445
# [270]	validation-auc:0.83515	train-auc:0.84451
# [271]	validation-auc:0.83520	train-auc:0.84456
# [272]	validation-auc:0.83526	train-auc:0.84462
# [273]	validation-auc:0.83535	train-auc:0.84474
# [274]	validation-auc:0.83545	train-auc:0.84485
# [275]	validation-auc:0.83552	train-auc:0.84495
# [276]	validation-auc:0.83559	train-auc:0.84503
# [277]	validation-auc:0.83568	train-auc:0.84511
# [278]	validation-auc:0.83578	train-auc:0.84521
# [279]	validation-auc:0.83588	train-auc:0.84535
# [280]	validation-auc:0.83597	train-auc:0.84545
# [281]	validation-auc:0.83602	train-auc:0.84553
# [282]	validation-auc:0.83611	train-auc:0.84562
# [283]	validation-auc:0.83615	train-auc:0.84567
# [284]	validation-auc:0.83623	train-auc:0.84575
# [285]	validation-auc:0.83630	train-auc:0.84583
# [286]	validation-auc:0.83638	train-auc:0.84592
# [287]	validation-auc:0.83642	train-auc:0.84599
# [288]	validation-auc:0.83651	train-auc:0.84611
# [289]	validation-auc:0.83658	train-auc:0.84621
# [290]	validation-auc:0.83663	train-auc:0.84630
# [291]	validation-auc:0.83671	train-auc:0.84639
# [292]	validation-auc:0.83675	train-auc:0.84647
# [293]	validation-auc:0.83679	train-auc:0.84654
# [294]	validation-auc:0.83688	train-auc:0.84664
# [295]	validation-auc:0.83694	train-auc:0.84671
# [296]	validation-auc:0.83700	train-auc:0.84676
# [297]	validation-auc:0.83705	train-auc:0.84686
# [298]	validation-auc:0.83710	train-auc:0.84693
# [299]	validation-auc:0.83718	train-auc:0.84704
# [300]	validation-auc:0.83723	train-auc:0.84710
# [301]	validation-auc:0.83728	train-auc:0.84716
# [302]	validation-auc:0.83736	train-auc:0.84726
# [303]	validation-auc:0.83744	train-auc:0.84735
# [304]	validation-auc:0.83750	train-auc:0.84743
# [305]	validation-auc:0.83756	train-auc:0.84750
# [306]	validation-auc:0.83762	train-auc:0.84757
# [307]	validation-auc:0.83767	train-auc:0.84766
# [308]	validation-auc:0.83773	train-auc:0.84771
# [309]	validation-auc:0.83778	train-auc:0.84779
# [310]	validation-auc:0.83786	train-auc:0.84788
# [311]	validation-auc:0.83793	train-auc:0.84796
# [312]	validation-auc:0.83796	train-auc:0.84803
# [313]	validation-auc:0.83804	train-auc:0.84811
# [314]	validation-auc:0.83812	train-auc:0.84822
# [315]	validation-auc:0.83816	train-auc:0.84829
# [316]	validation-auc:0.83818	train-auc:0.84835
# [317]	validation-auc:0.83826	train-auc:0.84845
# [318]	validation-auc:0.83834	train-auc:0.84854
# [319]	validation-auc:0.83840	train-auc:0.84860
# [320]	validation-auc:0.83846	train-auc:0.84867
# [321]	validation-auc:0.83853	train-auc:0.84874
# [322]	validation-auc:0.83856	train-auc:0.84882
# [323]	validation-auc:0.83863	train-auc:0.84890
# [324]	validation-auc:0.83868	train-auc:0.84898
# [325]	validation-auc:0.83877	train-auc:0.84907
# [326]	validation-auc:0.83882	train-auc:0.84912
# [327]	validation-auc:0.83887	train-auc:0.84919
# [328]	validation-auc:0.83894	train-auc:0.84930
# [329]	validation-auc:0.83898	train-auc:0.84938
# [330]	validation-auc:0.83901	train-auc:0.84942
# [331]	validation-auc:0.83906	train-auc:0.84952
# [332]	validation-auc:0.83911	train-auc:0.84960
# [333]	validation-auc:0.83916	train-auc:0.84967
# [334]	validation-auc:0.83921	train-auc:0.84974
# [335]	validation-auc:0.83927	train-auc:0.84980
# [336]	validation-auc:0.83932	train-auc:0.84989
# [337]	validation-auc:0.83937	train-auc:0.84997
# [338]	validation-auc:0.83938	train-auc:0.85006
# [339]	validation-auc:0.83942	train-auc:0.85013
# [340]	validation-auc:0.83944	train-auc:0.85019
# [341]	validation-auc:0.83947	train-auc:0.85022
# [342]	validation-auc:0.83951	train-auc:0.85029
# [343]	validation-auc:0.83961	train-auc:0.85041
# [344]	validation-auc:0.83968	train-auc:0.85049
# [345]	validation-auc:0.83972	train-auc:0.85053
# [346]	validation-auc:0.83979	train-auc:0.85061
# [347]	validation-auc:0.83984	train-auc:0.85068
# [348]	validation-auc:0.83987	train-auc:0.85074
# [349]	validation-auc:0.83990	train-auc:0.85083
# [350]	validation-auc:0.83998	train-auc:0.85093
# [351]	validation-auc:0.84005	train-auc:0.85100
# [352]	validation-auc:0.84010	train-auc:0.85107
# [353]	validation-auc:0.84015	train-auc:0.85112
# [354]	validation-auc:0.84023	train-auc:0.85122
# [355]	validation-auc:0.84028	train-auc:0.85128
# [356]	validation-auc:0.84034	train-auc:0.85136
# [357]	validation-auc:0.84037	train-auc:0.85141
# [358]	validation-auc:0.84037	train-auc:0.85145
# [359]	validation-auc:0.84043	train-auc:0.85152
# [360]	validation-auc:0.84045	train-auc:0.85156
# [361]	validation-auc:0.84048	train-auc:0.85160
# [362]	validation-auc:0.84055	train-auc:0.85169
# [363]	validation-auc:0.84059	train-auc:0.85174
# [364]	validation-auc:0.84067	train-auc:0.85181
# [365]	validation-auc:0.84067	train-auc:0.85182
# [366]	validation-auc:0.84074	train-auc:0.85189
# [367]	validation-auc:0.84076	train-auc:0.85193
# [368]	validation-auc:0.84079	train-auc:0.85198
# [369]	validation-auc:0.84084	train-auc:0.85205
# [370]	validation-auc:0.84088	train-auc:0.85211
# [371]	validation-auc:0.84095	train-auc:0.85220
# [372]	validation-auc:0.84099	train-auc:0.85223
# [373]	validation-auc:0.84102	train-auc:0.85226
# [374]	validation-auc:0.84105	train-auc:0.85232
# [375]	validation-auc:0.84110	train-auc:0.85240
# [376]	validation-auc:0.84114	train-auc:0.85246
# [377]	validation-auc:0.84117	train-auc:0.85253
# [378]	validation-auc:0.84121	train-auc:0.85259
# [379]	validation-auc:0.84126	train-auc:0.85265
# [380]	validation-auc:0.84129	train-auc:0.85270
# [381]	validation-auc:0.84136	train-auc:0.85279
# [382]	validation-auc:0.84143	train-auc:0.85286
# [383]	validation-auc:0.84147	train-auc:0.85293
# [384]	validation-auc:0.84152	train-auc:0.85298
# [385]	validation-auc:0.84156	train-auc:0.85303
# [386]	validation-auc:0.84159	train-auc:0.85311
# [387]	validation-auc:0.84163	train-auc:0.85316
# [388]	validation-auc:0.84167	train-auc:0.85321
# [389]	validation-auc:0.84169	train-auc:0.85327
# [390]	validation-auc:0.84174	train-auc:0.85332
# [391]	validation-auc:0.84180	train-auc:0.85339
# [392]	validation-auc:0.84181	train-auc:0.85343
# [393]	validation-auc:0.84185	train-auc:0.85349
# [394]	validation-auc:0.84190	train-auc:0.85354
# [395]	validation-auc:0.84193	train-auc:0.85358
# [396]	validation-auc:0.84197	train-auc:0.85362
# [397]	validation-auc:0.84201	train-auc:0.85366
# [398]	validation-auc:0.84205	train-auc:0.85370
# [399]	validation-auc:0.84211	train-auc:0.85376
# CPU times: user 29min 19s, sys: 12min 15s, total: 41min 35s
# Wall time: 41min 30s

# %%
test140 = pd.read_csv('../data/external/sentiment140/testdata.manual.2009.06.14.csv', encoding='latin-1', header=None, names=['sentiment', 'id', 'date', 'no_query', 'user', 'tweet'])
test140 = cudf.from_pandas(test140)
test140 = test140[['tweet', 'user', 'sentiment']]
test140['sentiment'] = (test140['sentiment']==4).astype(int)
tfidf_test = vec.transform(test140['tweet'])
test_cpu = tfidf_test.get()
dtest = xgb.DMatrix(test_cpu)

# %%
predictions_lr_nought_1 = bst_lr_nought_1.predict(dtest)
predictions_lr_nought_3 = bst_lr_nought_3.predict(dtest)
predictions_lr_nought_3_400_round = bst_lr_nought_3_400_round.predict(dtest)

# %%
display_scores(predictions_lr_nought_1, test140)
# Out:
# Accuracy: 0.5421686746987951
# Precision: 0.8681318681318682
# Auc: 0.6299967500812479
# Recall: 0.43646408839779005

# %%
display_scores(predictions_lr_nought_3, test140)
# Out:
# Accuracy: 0.5923694779116466
# Precision: 0.8901098901098901
# Auc: 0.6694231315714692
# Recall: 0.46956521739130436

# %%
display_scores(predictions_lr_nought_3_400_round, test140)
# Out:
# Accuracy: 0.6124497991967871
# Precision: 0.8681318681318682
# Auc: 0.6714147754707871
# Recall: 0.4831804281345566

# %%
bst_lr_nought_1.save_model('../models/xgboost/bst_lr_nought_1.save')
bst_lr_nought_1.dump_model('../models/xgboost/bst_lr_nought_1.dump')

# %%
bst_lr_nought_3.save_model('../models/xgboost/bst_lr_nought_3.save')
bst_lr_nought_3.dump_model('../models/xgboost/bst_lr_nought_3.dump')

# %%
bst_lr_nought_3_400_round.save_model('../models/xgboost/bst_lr_nought_3_400_round.save')
bst_lr_nought_3_400_round.dump_model('../models/xgboost/bst_lr_nought_3_400_round.dump')

# %%
train_kaggle = pd.read_csv('../data/external/kaggle/train.csv')
train_kaggle = cudf.from_pandas(train_kaggle)
tfidf_kaggle_train = vec.transform(train_kaggle['text'])
tfidf_kaggle_train_cpu = tfidf_kaggle_train.get()
dkaggle_train = xgb.DMatrix(tfidf_kaggle_train_cpu)

# %%
train_sent_lr_nought_1 = bst_lr_nought_1.predict(dkaggle_train)
train_sent_lr_nought_3 = bst_lr_nought_3.predict(dkaggle_train)
train_sent_lr_nought_3_400_round = bst_lr_nought_3_400_round.predict(dkaggle_train)

# %%
test_kaggle = pd.read_csv('../data/external/kaggle/test.csv')
test_kaggle = cudf.from_pandas(test_kaggle)
tfidf_kaggle_test = vec.transform(test_kaggle['text'])
tfidf_kaggle_test_cpu = tfidf_kaggle_test.get()
dkaggle_test = xgb.DMatrix(tfidf_kaggle_test_cpu)

# %%
test_sent_lr_nought_1 = bst_lr_nought_1.predict(dkaggle_test)
test_sent_lr_nought_3 = bst_lr_nought_3.predict(dkaggle_test)
test_sent_lr_nought_3_400_round = bst_lr_nought_3_400_round.predict(dkaggle_test)

# %%
with open('../data/features/train_sent_lr_nought_1.npy', 'wb') as f:
    np.save(f, train_sent_lr_nought_1)
with open('../data/features/train_sent_lr_nought_3.npy', 'wb') as f:
    np.save(f, train_sent_lr_nought_3_400_round)
with open('../data/features/train_sent_lr_nought_3_400_round.npy', 'wb') as f:
    np.save(f, train_sent_lr_nought_3_400_round)
with open('../data/features/test_sent_lr_nought_1.npy', 'wb') as f:
    np.save(f, test_sent_lr_nought_1)
with open('../data/features/test_sent_lr_nought_3.npy', 'wb') as f:
    np.save(f, test_sent_lr_nought_3)
with open('../data/features/test_sent_lr_nought_3_400_round.npy', 'wb') as f:
    np.save(f, test_sent_lr_nought_3_400_round)
